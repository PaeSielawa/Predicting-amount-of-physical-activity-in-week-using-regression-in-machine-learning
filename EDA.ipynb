# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
"""
Task 2.2

Biases and assumptions:
  - If family has history with overweight it is very possible that you also have overweight

  - Eating high caloric food couse overweight

  - Lack of vegetables may increase possibility of overweight

  - Eating between meals can couse overweight

  - The more main meals do you eat daily u may have overweight

  - Smoke may couse underweight

  - Not monitoring daily calories can lead to overweight

  - Lack of physical activity can increase possibility of overweight

  - The more time on books, cell phone, television etc.. increase possible of overweight

  - Drinking alcohol can couse overweight
"""
# Out:
# '\nTask 2.2\n\nBiases and assumptions:\n  - If family has history with overweight it is very possible that you also have overweight\n\n  - Eating high caloric food couse overweight\n\n  - Lack of vegetables may increase possibility of overweight\n\n  - Eating between meals can couse overweight\n\n  - The more main meals do you eat daily u may have overweight\n\n  - Smoke may couse underweight\n\n  - Not monitoring daily calories can lead to overweight\n\n  - Lack of physical activity can increase possibility of overweight\n\n  - The more time on books, cell phone, television etc.. increase possible of overweight\n\n  - Drinking alcohol can couse overweight\n'

# %%
"""
Task 2.3

77% of the data was generated synthetically using the Weka tool and SMOTE filter,
23% of the data was collected directly from users through a web platform


"""
# Out:
# '\nTask 2.3\n\n77% of the data was generated synthetically using the Weka tool and SMOTE filter,\n23% of the data was collected directly from users through a web platform\n\n\n'

# %%
# Task 2.5
data = pd.read_csv('/content/drive/MyDrive/sample_data/EstimationOfObesityLevels.csv')
data.head(10)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
# 5    Male  29.0    1.62    53.0                             no  yes   2.0
# 6  Female  23.0    1.50    55.0                            yes  yes   3.0
# 7    Male  22.0    1.64    53.0                             no   no   2.0
# 8    Male  24.0    1.78    64.0                            yes  yes   3.0
# 9    Male  22.0    1.72    68.0                            yes  yes   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# ...

# %%
# Task 2.6

X = data.drop('NObeyesdad', axis = 1)
y = data['NObeyesdad']

X_test, X_temp, y_test, y_temp = train_test_split(X, y, test_size=0.7, random_state=42)

# %%
# Task 2.7
# 1)
sns.barplot(data=data['CAEC']).set(title="Do you eat any food between meals?")
# Out:
# [Text(0.5, 1.0, 'Do you eat any food between meals?')]

# %%
sns.barplot(data=data['CALC']).set(title="How often do you drink alcohol?")
# Out:
# [Text(0.5, 1.0, 'How often do you drink alcohol?')]

# %%
sns.barplot(data=data['MTRANS']).set(title="Which transportation do you usually use?")
# Out:
# [Text(0.5, 1.0, 'Which transportation do you usually use?')]

# %%
sns.barplot(data=data['NObeyesdad']).set(title="Obesity level")
# Out:
# [Text(0.5, 1.0, 'Obesity level')]

# %%
sns.barplot(data=data['family_history_with_overweight']).set(title="Has a family member suffered or suffers from overweight?")
# Out:
# [Text(0.5, 1.0, 'Has a family member suffered or suffers from overweight?')]

# %%
sns.barplot(data=data['FAVC']).set(title="Do you eat high caloric food frequently?")
# Out:
# [Text(0.5, 1.0, 'Do you eat high caloric food frequently?')]

# %%
sns.barplot(data=data['SMOKE']).set(title="Do you smoke?")
# Out:
# [Text(0.5, 1.0, 'Do you smoke?')]

# %%
sns.barplot(data=data['SCC']).set(title="Do you monitor the calories you eat daily?")
# Out:
# [Text(0.5, 1.0, 'Do you monitor the calories you eat daily?')]

# %%
sns.histplot(data=data['Age']).set(title="Age")
# Out:
# [Text(0.5, 1.0, 'Age')]

# %%
sns.histplot(data=data['Weight']).set(title="Weight")
# Out:
# [Text(0.5, 1.0, 'Weight')]

# %%
sns.histplot(data=data['Height']).set(title="Height")
# Out:
# [Text(0.5, 1.0, 'Height')]

# %%
sns.histplot(data=data['FCVC']).set(title="Do you usually eat vegetables in your meals?")
# Out:
# [Text(0.5, 1.0, 'Do you usually eat vegetables in your meals?')]

# %%
sns.histplot(data=data['NCP']).set(title="How many main meals do you have daily?")
# Out:
# [Text(0.5, 1.0, 'How many main meals do you have daily')]

# %%
sns.histplot(data=data['CH2O']).set(title="How much water do you drink daily?")
# Out:
# [Text(0.5, 1.0, 'How much water do you drink daily?')]

# %%
sns.histplot(data=data['FAF']).set(title="How often do you have physical activity?")
# Out:
# [Text(0.5, 1.0, 'How often do you have physical activity?')]

# %%
sns.histplot(data=data['TUE']).set(title="How much time do you use technological devices?")
# Out:
# [Text(0.5, 1.0, 'How much time do you use technological devices?')]

# %%
# 3)
plt.figure(figsize=(15, 5))
sns.boxplot(x=data['NObeyesdad'], y=data['Weight']).set(title="?")
# Out:
# [Text(0.5, 1.0, '?')]

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x=data['NObeyesdad'], y=data['Height']).set(title="?")
# Out:
# [Text(0.5, 1.0, '?')]

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x=data['CAEC'], y=data['Weight']).set(title="Weight vs Do you eat any food between meals?")
# Out:
# [Text(0.5, 1.0, 'Weight vs Do you eat any food between meals?')]

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=data['Weight'], y=data['Height'], hue=data['NObeyesdad']).set(title="?")
# Out:
# [Text(0.5, 1.0, '?')]

# %%
"""
goal: Estimate how often do you have physical activity (FAF)

features: FAVC, FCVC, CAEC, CH2O, SCC, CALC, SMOKE, Weight


"""

# %%
sns.scatterplot(x=data['FAF'], y=data['CH2O']).set(title="How often do you have physical activity?")
# Out:
# [Text(0.5, 1.0, 'How often do you have physical activity?')]

# %%
xpp = data['FAF']
xpp.head()
# Out:
# 0    0.0
# 1    3.0
# 2    2.0
# 3    2.0
# 4    0.0
# Name: FAF, dtype: float64

# %%
data['FAF'].value_counts()
# Out:
# FAF
# 0.000000    411
# 1.000000    234
# 2.000000    183
# 3.000000     75
# 0.110174      2
#            ...
# 1.916751      1
# 0.954459      1
# 0.340915      1
# 0.986414      1
# 1.026452      1
# Name: count, Length: 1190, dtype: int64

# %%
data_filtered = data[data['FAF'].isin([0, 1, 2, 3])]

# %%
data_filtered['FAF'].value_counts()
# Out:
# FAF
# 0.0    411
# 1.0    234
# 2.0    183
# 3.0     75
# Name: count, dtype: int64
